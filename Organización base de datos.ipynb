# %%
# Instalación de Complementos
# !pip install pandas openpyxl
# !pip install wordcloud
# !pip install sweetviz
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Cargamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from collections import Counter
import re
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv

# %%
# Se carga la base de datos de servicio tecnico
file_path = 'Informe Servicio Técnico Diagnostico de equipos (2)(Sheet1).csv'

# Lee el archivo CSV especificando el códec
S_tecnico = pd.read_csv(file_path, encoding='latin1')

# Muestra las primeras filas del DataFrame
S_tecnico.head()
# Out:
#   Fecha de visita            Empresa                            Planta  \
# 0       1/16/2020             HOLCIM                   HOLCIM COLOMBIA
# 1      05/08/2017  INGENIO RISARALDA                         RISARALDA
# 2             NaN                NaN                               NaN
# 3      05/08/2017  INGENIO RISARALDA                         RISARALDA
# 4       1/26/2024   INGENIO RIOPAILA  INGENIO RIOPAILA PLANTA CASTILLA
#
#        País   Ciudad            Tipo de equipo Orden de compra Pedido N°  \
# 0  COLOMBIA   BOYACÁ       Elevador cangilones             NaN     23996
# 1  COLOMBIA   BALBOA  Tansportador de tablilla      3620161243     20561
# 2       NaN      NaN                       NaN             NaN       NaN
# 3  COLOMBIA   BALBOA  Tansportador de tablilla      3620161243     20561
# 4  COLOMBIA  PRADERA  Tansportador de tablilla      2000508616     27035
#
#   Fecha de instalación de la cadena Material  ...  \
# ...

# %%
# Se carga la base de datos de planta virtual
file_path = 'Planta Virtual(Hoja1).csv'

# Lee el archivo CSV especificando el códec
Planta = pd.read_csv(file_path, encoding='latin1')

# Muestra las primeras filas del DataFrame
Planta.head()
# Out:
#    ConsecutivoOP  ConsecPedido          Cliente                NombCliente  \
# 0          61838       25687.0        890906407     FORJAS BOLIVAR S.A.S..
# 1          43746       20071.0  46505-96-303869         MINERA PANAMA SA
# 2          64305       26451.0       43-1701740          WEAR CONCEPTS INC
# 3          79635       30410.0        900087414     RIOPAILA CASTILLA S.A.
# 4          45313       20591.0      20419387658  CEMENTOS PACASMAYO S.A.A.
#
#       Producto                    NombProducto          FechElab     Proceso  \
# 0   PD0001779C           PASADOR 35.84X30X76.8  10/29/2020 14:47  PD0001779C
# 1     PD000500     ESP M10X1.5X70 GDO 4.6 ZINC    5/3/2017 13:43    PD000500
# 2  PD000560-2A        BUJE ØE60.5XØI32.2X139.8   5/21/2021 13:47  PD0005602A
# 3     PD000814       TLLO CARJE 3/4X10HX2 GDO8    1/23/2024 7:13    PD000814
# 4   681-00065D  PTNA SOPORTE3.17X171.45X349.25   8/28/2017 16:18    PD01262D
#
# ...

# %%
# Se verificar valores unicos de pedidos en servicio tecnico
S_tecnico['Pedido N°'].unique()
# Out:
# array(['23996', '20561', nan, '27035', '29137', '24723', '30020', '25961',
#        '23311', '26046', '26425', '28508;28509', '26033', '26765',
#        '29830', '27177', '27380, 26425', '27553', '27037', '24775',
#        '27587', '27758', '28914', '30028'], dtype=object)

# %%
# Reemplazar el valor '28508;28509' por '28508' en la columna 'Pedido N°' para quedarse con una unico valor debido a 
# que es el unico con valor diferente
S_tecnico['Pedido N°'] = S_tecnico['Pedido N°'].replace('28508;28509', '28508')
S_tecnico['Pedido N°'] = S_tecnico['Pedido N°'].replace('27380, 26425', '27380')

# Verificar el cambio
print(S_tecnico['Pedido N°'].unique())
# Out:
# ['23996' '20561' nan '27035' '29137' '24723' '30020' '25961' '23311'
#  '26046' '26425' '28508' '26033' '26765' '29830' '27177' '27380' '27553'
#  '27037' '24775' '27587' '27758' '28914' '30028']

# %%
# se verifica tamaño
S_tecnico.shape
# Out:
# (29, 33)

# %%
# Función para limpiar los valores de la columna
def limpiar_valor(valor):
    if isinstance(valor, str):  # Solo aplica las transformaciones si el valor es de tipo str
        valor = valor.strip()
        valor = valor.replace(',', '')
    return valor

# Aplica la función de limpieza a la columna 'Pedido N°'
S_tecnico['Pedido N°'] = S_tecnico['Pedido N°'].apply(limpiar_valor)

# Ahora intenta convertir a float64
S_tecnico['Pedido N°'] = pd.to_numeric(S_tecnico['Pedido N°'], errors='coerce')

# Verifica el nuevo tipo de la columna
print(S_tecnico['Pedido N°'].dtype)

# Muestra los primeros datos para verificar el cambio
print(S_tecnico.head())
# Out:
# float64
#   Fecha de visita            Empresa                            Planta  \
# 0       1/16/2020             HOLCIM                   HOLCIM COLOMBIA
# 1      05/08/2017  INGENIO RISARALDA                         RISARALDA
# 2             NaN                NaN                               NaN
# 3      05/08/2017  INGENIO RISARALDA                         RISARALDA
# 4       1/26/2024   INGENIO RIOPAILA  INGENIO RIOPAILA PLANTA CASTILLA
#
#        País   Ciudad            Tipo de equipo Orden de compra  Pedido N°  \
# 0  COLOMBIA   BOYACÁ       Elevador cangilones             NaN    23996.0
# 1  COLOMBIA   BALBOA  Tansportador de tablilla      3620161243    20561.0
# 2       NaN      NaN                       NaN             NaN        NaN
# 3  COLOMBIA   BALBOA  Tansportador de tablilla      3620161243    20561.0
# 4  COLOMBIA  PRADERA  Tansportador de tablilla      2000508616    27035.0
#
#   Fecha de instalación de la cadena Material  ...  \
# ...

# %%
# Se veririca tipo de variable
S_tecnico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 33 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Fecha de visita                                     28 non-null     object
#  1   Empresa                                             28 non-null     object
#  2   Planta                                              27 non-null     object
#  3   País                                                28 non-null     object
#  4   Ciudad                                              28 non-null     object
#  5   Tipo de equipo                                      28 non-null     object
#  6   Orden de compra                                     23 non-null     object
#  7   Pedido N°                                           26 non-null     float64
# ...

# %%
print("\nNúmero de datos faltantes por columna:")
print(S_tecnico.isnull().sum())
# Out:
# Número de datos faltantes por columna:
# Fecha de visita                                        1
# Empresa                                                1
# Planta                                                 2
# País                                                   1
# Ciudad                                                 1
# Tipo de equipo                                         1
# Orden de compra                                        6
# Pedido N°                                              3
# Fecha de instalación de la cadena                      4
# Material                                               4
# Referencia equipo                                      2
# Causa de desgaste                                      3
# Si escogió otros, cuál?                               13
# Escoja el desgaste donde se presenta                   1
# Tipo de cadena                                         1
# Referencia cadena                                      1
# ...

# %%
# Se verifica tipo de variable
Planta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244637 entries, 0 to 244636
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ConsecutivoOP    244637 non-null  int64
#  1   ConsecPedido     241467 non-null  float64
#  2   Cliente          243902 non-null  object
#  3   NombCliente      244637 non-null  object
#  4   Producto         244637 non-null  object
#  5   NombProducto     244637 non-null  object
#  6   FechElab         244637 non-null  object
#  7   Proceso          244637 non-null  object
#  8   Version          244637 non-null  int64
#  9   FechEntregaPdcc  137707 non-null  object
#  10  FechEntregaClte  244384 non-null  object
#  11  OCCliente        244637 non-null  object
#  12  QtyRequerida     244637 non-null  float64
#  13  Actividad        244637 non-null  object
#  14  QtyControl       244637 non-null  int64
#  15  RecMAQ           244637 non-null  object
# ...

# %%
# Reemplaza 'ConsecPedido' con el nombre exacto de la columna en el dataframe Planta
consec_pedido_col = 'ConsecPedido'

# Realiza la comparación y actualización
for index, row in S_tecnico.iterrows():
    pedido_num = row['Pedido N°']
    # Verifica si el valor de "Pedido N°" está en "ConsecPedido" de Planta
    if pedido_num in Planta[consec_pedido_col].values:
        # Encuentra las filas correspondientes en Planta
        planta_indices = Planta[Planta[consec_pedido_col] == pedido_num].index
        for i in planta_indices:
            # Copia todas las columnas de S_tecnico a Planta
            for col in S_tecnico.columns:
                Planta.at[i, col] = row[col]
    else:
        print(f"No hay coincidencias para Pedido N°: {pedido_num}")
# Out:
# C:\Users\cesar\AppData\Local\Temp\ipykernel_9008\2268806346.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1/16/2020' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Planta.at[i, col] = row[col]
# C:\Users\cesar\AppData\Local\Temp\ipykernel_9008\2268806346.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'HOLCIM' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Planta.at[i, col] = row[col]
# C:\Users\cesar\AppData\Local\Temp\ipykernel_9008\2268806346.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'HOLCIM COLOMBIA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Planta.at[i, col] = row[col]
# ...

# %%
# Se verifica el tamañao del nuevo dataframe
Planta.head(10)
# Out:
#    ConsecutivoOP  ConsecPedido          Cliente                NombCliente  \
# 0          61838       25687.0        890906407     FORJAS BOLIVAR S.A.S..
# 1          43746       20071.0  46505-96-303869         MINERA PANAMA SA
# 2          64305       26451.0       43-1701740          WEAR CONCEPTS INC
# 3          79635       30410.0        900087414     RIOPAILA CASTILLA S.A.
# 4          45313       20591.0      20419387658  CEMENTOS PACASMAYO S.A.A.
# 5          57216       24304.0        901218630        MINEROS ALUVIAL SAS
# 6          45831       20818.0        899999068             ECOPETROL S.A.
# 7          43746       20071.0  46505-96-303869         MINERA PANAMA SA
# 8              7       23414.0        860002523        CEMEX COLOMBIA S.A.
# 9          52530       22769.0           110907           BUZZI UNICEM USA
#
#       Producto                    NombProducto          FechElab     Proceso  \
# ...

# %%
# Se verifica las columnas del nuevo dataframe
Planta.columns
# Out:
# Index(['ConsecutivoOP', 'ConsecPedido', 'Cliente', 'NombCliente', 'Producto',
#        'NombProducto', 'FechElab', 'Proceso', 'Version', 'FechEntregaPdcc',
#        'FechEntregaClte', 'OCCliente', 'QtyRequerida', 'Actividad',
#        'QtyControl', 'RecMAQ', 'RecHOM', 'SecAct', 'FechEstInicil', 'estado',
#        'TipoConsecutivo', 'Fecha de visita', 'Empresa', 'Planta', 'País',
#        'Ciudad', 'Tipo de equipo', 'Orden de compra', 'Pedido N°',
#        'Fecha de instalación de la cadena', 'Material', 'Referencia equipo',
#        'Causa de desgaste', 'Si escogió otros, cuál?',
#        'Escoja el desgaste donde se presenta', 'Tipo de cadena',
#        'Referencia cadena',
#        'Medida referencia de control desgaste nueva en mm',
#        'Medida referencia control de desgaste actual en mm',
#        'Porcentaje de elongación actual %', 'Porcentaje de elongación máx %',
#        'Proyección en horas de operación restantes (H)',
# ...

# %%
#Se verifica el tamaño del DF
Planta.shape
# Out:
# (244637, 54)

# %%
# Mostrar las primeras filas del DataFrame para asegurarse de que se ha cargado correctamente

# Número de registros y columnas
print("\nNúmero de registros y columnas:")
print(Planta.shape)

# Tipos de variables para cada columna
print("\nTipos de variables para cada columna:")
print(Planta.dtypes)

# Número de datos faltantes por columna
print("\nNúmero de datos faltantes por columna:")
print(Planta.isnull().sum())
# Out:
# Número de registros y columnas:
# (244637, 54)
#
# Tipos de variables para cada columna:
# ConsecutivoOP                                           int64
# ConsecPedido                                          float64
# Cliente                                                object
# NombCliente                                            object
# Producto                                               object
# NombProducto                                           object
# FechElab                                               object
# Proceso                                                object
# Version                                                 int64
# FechEntregaPdcc                                        object
# FechEntregaClte                                        object
# OCCliente                                              object
# QtyRequerida                                          float64
# Actividad                                              object
# ...

# %%
# Generación de información de datos por dataframe

# Mostrar las primeras filas del DataFrame para asegurarse de que se ha cargado correctamente
primeras_filas = Planta.head()

# Número de registros y columnas
num_registros_columnas = pd.DataFrame({
    'Descripción': ['Número de registros', 'Número de columnas'],
    'Valor': [Planta.shape[0], Planta.shape[1]]
})

# Tipos de variables para cada columna
tipos_de_variables = Planta.dtypes.reset_index()
tipos_de_variables.columns = ['Columna', 'Tipo de Dato']

# Número de datos faltantes por columna
datos_faltantes = Planta.isnull().sum().reset_index()
datos_faltantes.columns = ['Columna', 'Datos Faltantes']

# Crear un ExcelWriter para guardar múltiples DataFrames en un solo archivo Excel
with pd.ExcelWriter('informe_analisis_planta.xlsx', engine='openpyxl') as writer:
    # Guardar las primeras filas del DataFrame
    primeras_filas.to_excel(writer, sheet_name='Primeras Filas', index=False)
    
    # Guardar el número de registros y columnas
    num_registros_columnas.to_excel(writer, sheet_name='Registros y Columnas', index=False)
    
    # Guardar los tipos de variables en una hoja separada
    tipos_de_variables.to_excel(writer, sheet_name='Tipos de Variables', index=False)
    
    # Guardar los datos faltantes en una hoja separada
    datos_faltantes.to_excel(writer, sheet_name='Datos Faltantes', index=False)

print("Informe generado y guardado como 'informe_analisis_planta.xlsx'")
# Out:
# Informe generado y guardado como 'informe_analisis_planta.xlsx'

# %%
# Observamos cuantos valores unicos existen en planta
Valores_unicos=Planta['Pedido N°'].nunique()
print(f"El número de valores únicos en la columna 'Pedido N°' es: {Valores_unicos}")
# Out:
# El número de valores únicos en la columna 'Pedido N°' es: 22

# %%
# Obtenemos los valores únicos en la columna "Pedido N°"
unique_values = Planta['Pedido N°'].unique()

print("Los valores únicos en la columna 'Pedido N°' son:")
print(unique_values)
# Out:
# Los valores únicos en la columna 'Pedido N°' son:
# [   nan 26765. 24723. 30020. 29830. 23311. 26425. 28914. 27037. 28508.
#  27177. 26033. 27380. 23996. 30028. 27587. 24775. 27553. 26046. 27758.
#  29137. 25961. 20561.]

# %%
# Eliminar filas con valores nulos en la columna "Pedido N°"
Planta = Planta.dropna(subset=['Pedido N°'])

# %%
# Se vrrifica nuevamente el tamaño
Planta.shape
# Out:
# (1903, 54)

# %%
# dataframe actualizado de planta en un archivo CSV
Planta.to_csv('Planta_act.csv', index=False)
